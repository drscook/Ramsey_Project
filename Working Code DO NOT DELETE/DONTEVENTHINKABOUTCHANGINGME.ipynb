# %% [markdown]
# Why Python?
# - convenience commands
# - visualization
# - syntx is simpler
# - jupyter notebooks
#
# Why not Python?
# - slow
#
# Why CUDA?
# - Super fast
#
# Why not CUDA?
# - complicated -> long development times
#
# ** Let's do  both **

# %% [markdown]
# ** Ramsey numbers **
# - A **graph** is a set of vertices and some edges between them (network)
# - A _k-clique_ in a graph is a set of k vertices where all **possible** edges are actually present
# - Pick n = number of vertices
# - Draw the complete graph K_n.  It's an n-clique.  Every set of k vertices form a k-clique.
# - Color each **edge** either 0=red or 1=blue.
#
# R(k,l)=n means
# - It **is** possible to color K_n where no k-clique is completely red and no l-clique is completely blue
# - This is **not** possible for any larger number of vertices.  Aka - ALL colorings will have at least one all-red k-clique or all-blue l-clique.
# - They matter for computer scientists
#
#
# Let's think about coding R(10,3).  To code this problem, you'll need to list all the vertices:
#  - Vertices = np.arange(num_vertices)
#
# And all the edges:
#  - Edges = list(itertools.combinations(Vertices,2))
#
# And all the 10-cliques (the others are easy enough in C.  But this one is much trickier - 10 nested for loops?)
# - Cliques = itertools.combinations(Vertices,10)
#
# And all the 3-cliques
# - Cliques = itertools.combinations(Vertices,3)
#
# Want to change 10,3 to something else?  Want to add more numbers, say R(3,6,7,4)?  No problem.  Code scales automatically
#
# Want to try to check EVERY possible coloring?
# - That's crazy - (num colors)^(num edges)
# - But here's the Python code to try it: Colorings = itertools.product(Colors,num_edges)

# %%
Ramsey = [3,7]
num_vertices = 24
num_steps = 200


#Ramsey = [3,3,4]
#num_vertices = 30
#num_steps = 1000000000


beta = 4
coloring = main_random(Ramsey, num_vertices, num_steps, beta=beta)
# Out:
# #blocks = gridDim.x = 680, cliques per block = threads per block = blockDim.x = 512, edges per thread = 21
# (680, 512, 21)
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 2 steps done in 0:00:02.  Best coloring so far was step 2 with 247 problems.  Time now 2017-06-22 14:19:36.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 5 steps done in 0:00:02.  Best coloring so far was step 5 with 246 problems.  Time now 2017-06-22 14:19:36.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 8 steps done in 0:00:02.  Best coloring so far was step 8 with 244 problems.  Time now 2017-06-22 14:19:36.
# getting from gpu
# Pandas and Cuda agree!!
# 9 steps done in 0:00:02.  Best coloring so far was step 9 with 238 problems.  Time now 2017-06-22 14:19:36.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 12 steps done in 0:00:02.  Best coloring so far was step 12 with 234 problems.  Time now 2017-06-22 14:19:36.
# getting from gpu
# Pandas and Cuda agree!!
# 13 steps done in 0:00:02.  Best coloring so far was step 13 with 226 problems.  Time now 2017-06-22 14:19:37.
# getting from gpu
# Pandas and Cuda agree!!
# 14 steps done in 0:00:02.  Best coloring so far was step 14 with 219 problems.  Time now 2017-06-22 14:19:37.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 16 steps done in 0:00:02.  Best coloring so far was step 16 with 214 problems.  Time now 2017-06-22 14:19:37.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 19 steps done in 0:00:02.  Best coloring so far was step 19 with 208 problems.  Time now 2017-06-22 14:19:37.
# getting from gpu
# Pandas and Cuda agree!!
# 20 steps done in 0:00:02.  Best coloring so far was step 20 with 203 problems.  Time now 2017-06-22 14:19:37.
# getting from gpu
# Pandas and Cuda agree!!
# 21 steps done in 0:00:02.  Best coloring so far was step 21 with 200 problems.  Time now 2017-06-22 14:19:37.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 23 steps done in 0:00:02.  Best coloring so far was step 23 with 195 problems.  Time now 2017-06-22 14:19:37.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 25 steps done in 0:00:02.  Best coloring so far was step 25 with 191 problems.  Time now 2017-06-22 14:19:37.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 28 steps done in 0:00:02.  Best coloring so far was step 28 with 186 problems.  Time now 2017-06-22 14:19:37.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 30 steps done in 0:00:03.  Best coloring so far was step 30 with 182 problems.  Time now 2017-06-22 14:19:37.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 33 steps done in 0:00:03.  Best coloring so far was step 33 with 176 problems.  Time now 2017-06-22 14:19:37.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 37 steps done in 0:00:03.  Best coloring so far was step 37 with 170 problems.  Time now 2017-06-22 14:19:37.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 39 steps done in 0:00:03.  Best coloring so far was step 39 with 167 problems.  Time now 2017-06-22 14:19:37.
# getting from gpu
# Pandas and Cuda agree!!
# 40 steps done in 0:00:03.  Best coloring so far was step 40 with 162 problems.  Time now 2017-06-22 14:19:37.
# getting from gpu
# Pandas and Cuda agree!!
# 41 steps done in 0:00:03.  Best coloring so far was step 41 with 158 problems.  Time now 2017-06-22 14:19:37.
# getting from gpu
# Pandas and Cuda agree!!
# 42 steps done in 0:00:03.  Best coloring so far was step 42 with 153 problems.  Time now 2017-06-22 14:19:37.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 46 steps done in 0:00:03.  Best coloring so far was step 46 with 151 problems.  Time now 2017-06-22 14:19:37.
# getting from gpu
# Pandas and Cuda agree!!
# 47 steps done in 0:00:03.  Best coloring so far was step 47 with 149 problems.  Time now 2017-06-22 14:19:37.
# getting from gpu
# Pandas and Cuda agree!!
# 48 steps done in 0:00:03.  Best coloring so far was step 48 with 144 problems.  Time now 2017-06-22 14:19:37.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 54 steps done in 0:00:03.  Best coloring so far was step 54 with 141 problems.  Time now 2017-06-22 14:19:38.
# getting from gpu
# Pandas and Cuda agree!!
# 55 steps done in 0:00:03.  Best coloring so far was step 55 with 137 problems.  Time now 2017-06-22 14:19:38.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 64 steps done in 0:00:03.  Best coloring so far was step 64 with 135 problems.  Time now 2017-06-22 14:19:38.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 66 steps done in 0:00:04.  Best coloring so far was step 66 with 131 problems.  Time now 2017-06-22 14:19:38.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 70 steps done in 0:00:04.  Best coloring so far was step 70 with 127 problems.  Time now 2017-06-22 14:19:38.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 73 steps done in 0:00:04.  Best coloring so far was step 73 with 123 problems.  Time now 2017-06-22 14:19:38.
# getting from gpu
# Pandas and Cuda agree!!
# 74 steps done in 0:00:04.  Best coloring so far was step 74 with 120 problems.  Time now 2017-06-22 14:19:38.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 76 steps done in 0:00:04.  Best coloring so far was step 76 with 115 problems.  Time now 2017-06-22 14:19:38.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 78 steps done in 0:00:04.  Best coloring so far was step 78 with 112 problems.  Time now 2017-06-22 14:19:38.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 81 steps done in 0:00:04.  Best coloring so far was step 81 with 109 problems.  Time now 2017-06-22 14:19:38.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 83 steps done in 0:00:04.  Best coloring so far was step 83 with 108 problems.  Time now 2017-06-22 14:19:38.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 90 steps done in 0:00:04.  Best coloring so far was step 90 with 104 problems.  Time now 2017-06-22 14:19:39.
# getting from gpu
# Pandas and Cuda agree!!
# 91 steps done in 0:00:04.  Best coloring so far was step 91 with 103 problems.  Time now 2017-06-22 14:19:39.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 93 steps done in 0:00:04.  Best coloring so far was step 93 with 100 problems.  Time now 2017-06-22 14:19:39.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 96 steps done in 0:00:04.  Best coloring so far was step 96 with 96 problems.  Time now 2017-06-22 14:19:39.
# getting from gpu
# Pandas and Cuda agree!!
# 97 steps done in 0:00:04.  Best coloring so far was step 97 with 92 problems.  Time now 2017-06-22 14:19:39.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 102 steps done in 0:00:05.  Best coloring so far was step 102 with 90 problems.  Time now 2017-06-22 14:19:39.
# getting from gpu
# Pandas and Cuda agree!!
# 103 steps done in 0:00:05.  Best coloring so far was step 103 with 88 problems.  Time now 2017-06-22 14:19:39.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 106 steps done in 0:00:05.  Best coloring so far was step 106 with 84 problems.  Time now 2017-06-22 14:19:39.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 108 steps done in 0:00:05.  Best coloring so far was step 108 with 81 problems.  Time now 2017-06-22 14:19:39.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 112 steps done in 0:00:05.  Best coloring so far was step 112 with 78 problems.  Time now 2017-06-22 14:19:39.
# getting from gpu
# Pandas and Cuda agree!!
# 113 steps done in 0:00:05.  Best coloring so far was step 113 with 76 problems.  Time now 2017-06-22 14:19:39.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 116 steps done in 0:00:05.  Best coloring so far was step 116 with 75 problems.  Time now 2017-06-22 14:19:39.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 122 steps done in 0:00:05.  Best coloring so far was step 122 with 73 problems.  Time now 2017-06-22 14:19:39.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 126 steps done in 0:00:05.  Best coloring so far was step 126 with 70 problems.  Time now 2017-06-22 14:19:40.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 133 steps done in 0:00:05.  Best coloring so far was step 133 with 68 problems.  Time now 2017-06-22 14:19:40.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 136 steps done in 0:00:06.  Best coloring so far was step 136 with 65 problems.  Time now 2017-06-22 14:19:40.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 141 steps done in 0:00:06.  Best coloring so far was step 141 with 64 problems.  Time now 2017-06-22 14:19:40.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 147 steps done in 0:00:06.  Best coloring so far was step 147 with 63 problems.  Time now 2017-06-22 14:19:40.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 151 steps done in 0:00:06.  Best coloring so far was step 151 with 62 problems.  Time now 2017-06-22 14:19:40.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 154 steps done in 0:00:06.  Best coloring so far was step 154 with 61 problems.  Time now 2017-06-22 14:19:40.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 160 steps done in 0:00:06.  Best coloring so far was step 160 with 60 problems.  Time now 2017-06-22 14:19:41.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 163 steps done in 0:00:06.  Best coloring so far was step 163 with 58 problems.  Time now 2017-06-22 14:19:41.
# getting from gpu
# Pandas and Cuda agree!!
# 164 steps done in 0:00:06.  Best coloring so far was step 164 with 56 problems.  Time now 2017-06-22 14:19:41.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 170 steps done in 0:00:06.  Best coloring so far was step 170 with 55 problems.  Time now 2017-06-22 14:19:41.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 179 steps done in 0:00:07.  Best coloring so far was step 179 with 52 problems.  Time now 2017-06-22 14:19:41.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 183 steps done in 0:00:07.  Best coloring so far was step 183 with 50 problems.  Time now 2017-06-22 14:19:41.
# getting from gpu
# Pandas and Cuda agree!!
# 184 steps done in 0:00:07.  Best coloring so far was step 184 with 48 problems.  Time now 2017-06-22 14:19:41.
# getting from gpu
# Pandas and Cuda agree!!
# 185 steps done in 0:00:07.  Best coloring so far was step 185 with 47 problems.  Time now 2017-06-22 14:19:41.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# 194 steps done in 0:00:07.  Best coloring so far was step 194 with 45 problems.  Time now 2017-06-22 14:19:42.
# getting from gpu
# Pandas and Cuda agree!!
# 195 steps done in 0:00:07.  Best coloring so far was step 195 with 44 problems.  Time now 2017-06-22 14:19:42.
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# getting from gpu
# Pandas and Cuda agree!!
# FINISHED!!
#
# 200 steps done in 0:00:07.  Best coloring so far was step 195 with 44 problems.  Time now 2017-06-22 14:19:42.
#          edge  color
# 0      (0, 1)      0
# 1      (0, 2)      1
# 2      (0, 3)      1
# 3      (0, 4)      0
# 4      (0, 5)      0
# 5      (0, 6)      1
# 6      (0, 7)      1
# 7      (0, 8)      1
# 8      (0, 9)      0
# 9     (0, 10)      1
# 10    (0, 11)      1
# 11    (0, 12)      1
# 12    (0, 13)      1
# 13    (0, 14)      1
# 14    (0, 15)      1
# 15    (0, 16)      1
# 16    (0, 17)      0
# 17    (0, 18)      1
# 18    (0, 19)      1
# 19    (0, 20)      1
# 20    (0, 21)      1
# 21    (0, 22)      0
# 22    (0, 23)      1
# 23     (1, 2)      1
# 24     (1, 3)      1
# 25     (1, 4)      0
# 26     (1, 5)      1
# 27     (1, 6)      1
# 28     (1, 7)      1
# 29     (1, 8)      1
# ..        ...    ...
# 246  (15, 22)      1
# 247  (15, 23)      1
# 248  (16, 17)      1
# 249  (16, 18)      1
# 250  (16, 19)      1
# 251  (16, 20)      1
# 252  (16, 21)      1
# 253  (16, 22)      1
# 254  (16, 23)      0
# 255  (17, 18)      1
# 256  (17, 19)      1
# 257  (17, 20)      0
# 258  (17, 21)      0
# 259  (17, 22)      1
# 260  (17, 23)      1
# 261  (18, 19)      1
# 262  (18, 20)      1
# 263  (18, 21)      1
# 264  (18, 22)      1
# 265  (18, 23)      0
# 266  (19, 20)      0
# 267  (19, 21)      0
# 268  (19, 22)      1
# 269  (19, 23)      1
# 270  (20, 21)      1
# 271  (20, 22)      0
# 272  (20, 23)      0
# 273  (21, 22)      1
# 274  (21, 23)      1
# 275  (22, 23)      0
#
# [276 rows x 2 columns]

# %%
from setup import *
import pycuda.driver as cuda
import pycuda.autoinit
from pycuda.compiler import SourceModule
import pycuda.gpuarray as gpuarray

def main_random(Ramsey, num_vertices, num_steps, beta=2):
    start_time = datetime.datetime.now()
    print()

    def choose(n,k):
        return int(math.factorial(n)/math.factorial(k)/math.factorial(n-k))

    num_colors = len(Ramsey)
    Colors = np.arange(num_colors)
    Vertices = np.arange(num_vertices)
    Edges = list(it.combinations(Vertices,2))
    #reverse lookup for edges below.  Eg if slot 3 above contains edge (2,5), the the dict below has entry (2,5):3
    Edges_idx = dict((edge, idx) for idx,edge in enumerate(Edges)) 
    num_edges = len(Edges)

    threads_per_block = 512
    vertices_per_clique = Ramsey
    edges_per_clique = np.array([choose(v,2) for v in vertices_per_clique])
    cliques_per_color = np.asarray([choose(num_vertices,v) for v in vertices_per_clique])
    blocks_per_color = np.ceil(cliques_per_color / threads_per_block).astype('uint32')
    num_blocks = blocks_per_color.sum()
    cliques_per_block = np.ceil(cliques_per_color / blocks_per_color).astype('uint32')
    #The objects below tells each block which color and how many cliques/edges it will monitor.
    #Note each vector is repetitive.  If color 0 gets 7 blocks, the first 7 entries will be the same
    block_color = np.repeat(Colors,blocks_per_color).astype('uint32')
    block_num_cliques = np.repeat(cliques_per_block,blocks_per_color).astype('uint32')
    block_edges_per_clique = np.repeat(edges_per_clique,blocks_per_color).astype('uint32')
    
    #The object below assigns each block to a list of cliques.  For simplicity while
    #we construct a single matrix with a lot of unused entries.
    #For example, edges_per_clique is different for blocks monitoring different colors.
    #We could make a more complex structure that handles this (see old stable version)
    #but that makes it harder to pass to the GPU.  Instead, we simply fill all "invalid"
    #unused entries with the placeholder "num_edges", which is 1 more the the largest
    #legal edge_idx (because Python indexes [0,1,2,...,num_edges-1]).
    #When we color later, we color these slots with the placeholder num_colors.
    assign_Blocks_to_Cliques = np.full([num_blocks,cliques_per_block.max(),edges_per_clique.max()],
                                       fill_value=num_edges, dtype='uint32')

    #Counters that that tracks the next open block and thread on each block
    next_open_block = 0    
    next_open_thread = np.zeros(num_blocks,dtype='int')
    for color, clique_size in enumerate(Ramsey):
        #Creates a generator to produce all cliques (the list of vertices).
        Cliques = it.combinations(Vertices,clique_size)

        #Makes the vector [0,1,2,...,num_blocks-1,0,1,2,...,num_blocks-1,....] of length num_cliques
        assign_Cliques_to_Blocks = np.arange(cliques_per_color[color]) % blocks_per_color[color]
        #randomizes assignment, but maintains clique counts
        np.random.shuffle(assign_Cliques_to_Blocks)
        #Starts at next open block
        assign_Cliques_to_Blocks += next_open_block
        
        for clique_Vertices, block in zip(Cliques,assign_Cliques_to_Blocks):
            #Gets the list of edges in this clique
            clique_Edges = list(it.combinations(clique_Vertices,2))
            #Converts it to edge_idx
            clique_Edges_idx = [Edges_idx[edge] for edge in clique_Edges]
            #Writes it to the correct block and next open thread on that block
            assign_Blocks_to_Cliques[block,next_open_thread[block],:edges_per_clique[color]] = clique_Edges_idx            
            next_open_thread[block] += 1
        next_open_block += blocks_per_color[color]

#     print("Ramsey");print(Ramsey);print("edges per clique");print(edges_per_clique);print("cliques per color");print(cliques_per_color);print("blocks per color");print(blocks_per_color);print("cliques per block");print(cliques_per_block)
#     for (idx, block)  in enumerate(assign_Blocks_to_Cliques):
#         print()
#         print("block = "+str(idx));
#         print("color = "+str(block_color[idx]));
#         print("num_cliques = "+str(block_num_cliques[idx]));
#         print("edges per clique = "+str(block_edges_per_clique[idx]));
#         print(block.shape, block.dtype);
#         display(block);
#         display(compare)
  
    
    #Code below sets up the GPU checker
    block_color_gpu = gpuarray.to_gpu(block_color)
    #block_num_cliques = gpuarray.to_gpu(block_num_cliques)
    block_edges_per_clique_gpu = gpuarray.to_gpu(block_edges_per_clique)
    assign_Blocks_to_Cliques_gpu = gpuarray.to_gpu(assign_Blocks_to_Cliques)    

    mod = SourceModule("""
    __global__ void find_problems(int *block_color, int *edges_per_clique, int *edges, int *coloring, int *Problems, int edges_per_thread)
    {
        int color = block_color[blockIdx.x];
        int clique_idx = blockIdx.x*blockDim.x + threadIdx.x;
        int start = clique_idx*edges_per_thread;
        int end = start + edges_per_clique[blockIdx.x];
        int e = start;
        while((e < end) && (coloring[edges[e]] == color)){
            e++;
        }
        Problems[clique_idx] = (e >= end) ? 1 : 0;
    }
    """)
    
    G, B, edges_per_thread = assign_Blocks_to_Cliques_gpu.shape
    edges_per_thread = np.uint32(edges_per_thread)
    print("#blocks = gridDim.x = %d, cliques per block = threads per block = blockDim.x = %d, edges per thread = %d"%(G,B,edges_per_thread))
    func = mod.get_function("find_problems")
    def find_problems_cuda(coloring_gpu, printout=False, get_from_gpu=False):
        func(block_color_gpu, block_edges_per_clique_gpu, assign_Blocks_to_Cliques_gpu, coloring_gpu, Problems_gpu, edges_per_thread, block=(B,1,1), grid=(G,1), shared=0)
        if printout == True:
            get_from_gpu = True
        if get_from_gpu == True:
            print("getting from gpu")
            Problems_cpu = Problems_gpu.get()
            if printout == True:
                print_problems(Problems_cpu)
        else:
            Problems_cpu = []
        return gpuarray.sum(Problems_gpu).get().astype('int'), Problems_cpu

    
    #The code below setups the serial version of this algorithm in pandas on the CPU.
    #It is much slower than the gpu version, but can be used in the absence of a GPU
    #and to verify that the algorithms give the same answers.
    #We msut create the "comparison" array.  This is a bit complicated.
    #We will discuss 2 arrays: compare and the coloring array.
    #First, recall that num_colors is one larger than the biggest legal color since
    #Python indexes [0,1,...,num_colors-1]
    #Now, fix a block and let c = block_color[block].
    #Consider the [block, clique, edge] entry of compare.  It equals:
    #c IF edge < num_edges_per_clique for that block
    #num_colors IF clique >= num_edges_per_clique for that block
    #Why?  In general there are extra rows and columns not associated to a valid edge.
    #When we color the graph later, they are filled with num_colors.
    #We do NOT want the "space fillers" to affect problem count.
    #In the extra rows, we see [c,c,...,c,num_colors,num_colors,...,num_colors] in compare
    #But in the coloring array, all entries will equal num_colors.
    #Thus, it is NOT counted as a problem because the first several slots disagree.
    #Thus, these extra rows can NEVER counts as problems cliques, as desired.
    #Now, consider the extra columns.  All entries will equal num_colors.  This is true
    #for BOTH compare AND the coloring array.  Thus, a row counts as a problem
    #if and only if the first num_edges_per_clique "valid" entries also match.
    #Thus the extra columns do NOT alter the "problem status" for valid rows, as desired.

    compare = np.full_like(assign_Blocks_to_Cliques, fill_value=num_colors)
    print(assign_Blocks_to_Cliques.shape)
    for block in range(num_blocks):
        compare[block,:,:block_edges_per_clique[block]] = block_color[block]
    
    def find_problems_pandas(coloring, printout=False):
        X = coloring[assign_Blocks_to_Cliques]
        Y = (X == compare)
        Problems = np.all(Y,axis=-1)
        if printout == True:
            print_problems(Problems)
        return Problems.sum().astype('int'), Problems

    def print_problems(Problems):        
        Z = pd.DataFrame(Problems.astype('uint32'))
        Z.insert(0,'problems',Z.sum(axis=1))
        Z.insert(0,'color',block_color)
        Z = Z.T
        problem_idx = np.any(Z,axis=-1)
        problem_idx[:2] = True
        display(Z.ix[problem_idx,:])

    def print_status():
        now = datetime.datetime.now()
        elapsed = now - start_time
        print("%d steps done in %s.  Best coloring so far was step %d with %d problems.  Time now %s."
                   %(step,str(elapsed).split('.')[0],step_best,num_problems_best,str(now).split('.')[0]))

    
    #Initialize the Markov chain
    coloring_cpu = np.random.choice(Colors, size=num_edges+1, replace=True).astype('uint32')
    coloring_cpu[num_edges] = num_colors
    #Recall this last slot holds is a placeholder to handlge "extra" slots.  See discussion
    #of serial pandas algorithm above.
    coloring_best = coloring_cpu.copy()
    coloring_gpu = gpuarray.to_gpu(coloring_cpu.copy())
    
    #Problems_current = np.zeros(assign_Blocks_to_Cliques.shape[:-1]).astype('uint32')    
    Problems_gpu = gpuarray.GPUArray(assign_Blocks_to_Cliques.shape[:-1],dtype='uint32')
    

    #num_problems_current, Problems_current = find_problems_pandas(coloring_cpu, printout=False)
    #num_problems_current, Problems_current = find_problems_cuda(coloring_gpu, get_from_gpu=True, printout=False)
    num_problems_current, _ = find_problems_cuda(coloring_gpu, get_from_gpu=False, printout=False)    
    num_problems_proposed = num_problems_current    
    num_problems_best = num_problems_current
    #Problems_proposed = Problems_current.copy()
    #Problems_best = Problems_current.copy()

    step = 0
    step_best = step
    
    loop_length = 100000
    loop_step = 0
    loops_done = 0
    start_compute = datetime.datetime.now()
    for i in range(num_steps):
        if num_problems_best == 0:
            break
        
        edge_idx = np.random.randint(0,num_edges)
        color_delta = np.random.randint(1,num_colors)
        edge_color_old = coloring_cpu[edge_idx]
        #edge_color_new = (edge_color_old + color_Deltas[i]) % num_colors
        edge_color_new = (edge_color_old + color_delta) % num_colors
        coloring_cpu[edge_idx] = edge_color_new
        coloring_gpu.set(coloring_cpu)

#         The code below check the pandas and cuda versions against each other.
#         It is commented out by default because it slows things down.
#         If you want to use it, you also need to uncomment several lines above to activate the pandas algorithm.

        num_problems_proposed, Problems_proposed_pandas = find_problems_pandas(coloring_cpu)#, printout=True)
        num_problems_proposed, Problems_proposed_cuda = find_problems_cuda(coloring_gpu, get_from_gpu=True, printout=False)
        if np.all(Problems_proposed_pandas == Problems_proposed_cuda) == True:
            print("Pandas and Cuda agree!!")
        else:
            raise Exception("Pandas and Cuda disagree :()")
            
        num_problems_proposed, _ = find_problems_cuda(coloring_gpu, get_from_gpu=False, printout=False)
        num_problems_diff = num_problems_current - num_problems_proposed
        if num_problems_diff >= 0:
             #print("Proposed is better.  Accepting.")            
            num_problems_current = num_problems_proposed
            #Problems_current = Problems_proposed.copy()
            if num_problems_proposed < num_problems_best:
                step_best = step
                coloring_best = coloring_cpu.copy()
                num_problems_best = num_problems_proposed
                #Problems_best = Problems_proposed.copy()
                print_status()
        else:            
            accept = np.exp(beta * num_problems_diff)            
            r = np.random.random()
            #print("Proposed is worse.  But I will accept it anyway if I draw a number less than %.3f.  I drew %.3f." % (accept,r))            
            if r <= accept:            
                #print("So I accept the move even though it is worse.")                
                num_problems_current = num_problems_proposed
                #Problems_current = Problems_proposed.copy()
            else:                
                #print("So I reject.")
                coloring_cpu[edge_idx] = edge_color_old
        step += 1
        loop_step += 1
        if(loop_step >= loop_length):
            loops_done += 1
            loop_step = 0
            print_status()
            compute_time = (datetime.datetime.now() - start_compute).seconds
            steps_done = loops_done*loop_length
            rate = steps_done / compute_time
            job_time = (num_steps-steps_done)/rate
            m, s = divmod(job_time,60)
            h, m = divmod(m,60)
            d, h = divmod(h,24)
            y, d = divmod(d,365)
            print("At %.0f colorings/second, it'll take me %d years %d days %d hours %d minutes and %d seconds to complete the remaining steps."%
                  (rate,y,d,h,m,s))

    

    print("FINISHED!!")
    coloring_cpu = coloring_best.copy()
    coloring_gpu.set(coloring_best)
    num_problems_best, _   = find_problems_cuda(coloring_gpu,get_from_gpu=False, printout=False)
    
    print()
    print_status()
    final_coloring = pd.DataFrame()
    final_coloring['edge'] = Edges
    final_coloring['color'] = coloring_best[:num_edges]
    display(final_coloring)
    return final_coloring
